# %% [markdown]
# <a href="https://colab.research.google.com/github/MiracleCakra/Machine-Learning_Ganjil_2025/blob/main/Week13_JS13_Artificial%20Neural%20Network%20(ANN)%20dan%20Evaluasi%20Classifier/Praktikum_2__Library_Keras_dengan_JST.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Praktikum 2
# Pada praktikum ini kita akan menggunakan library Keras untuk menggunakan JST. Keras adalah API tingkat tinggi untuk membangun JST dengan mudah, sedangkan TensorFlow adalah framework yang mendukung Keras.
#
# Langkah:
#
# 1. Import library.
#
# 2. Load dataset.
#
# 3. Bangun model.
#
# 4. Kompilasi dan latih model.
#
# 5. Evaluasi hasil.
#
# 6. Klasifikasi Data Iris

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# One-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Bangun model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(10, activation='relu', input_shape=(4,)),
    tf.keras.layers.Dense(8, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Kompilasi
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Evaluasi
loss, acc = model.evaluate(X_test, y_test)
print(f"Akurasi: {acc}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.2635 - loss: 1.5567
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3151 - loss: 1.1172
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3070 - loss: 1.0198
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6194 - loss: 0.9512
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.6572 - loss: 0.8946
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7345 - loss: 0.8252
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.7114 - loss: 0.8130
# Epoch 8/50
# ...

# %% [markdown]
# # Tugas 2

# %% [markdown]
# ## Ubah jumlah neuron hidden layer.

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
import tensorflow as tf

# Load dataset
iris = load_iris()
X = iris.data
y = iris.target.reshape(-1, 1)

# One-hot encoding
encoder = OneHotEncoder(sparse_output=False)
y = encoder.fit_transform(y)

# Split data
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Bangun model
model = tf.keras.Sequential([
    tf.keras.layers.Dense(12, activation='relu', input_shape=(4,)),
    tf.keras.layers.Dense(10, activation='relu'),
    tf.keras.layers.Dense(3, activation='softmax')
])

# Kompilasi
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Latih model
model.fit(X_train, y_train, epochs=50, batch_size=8)

# Evaluasi
loss, acc = model.evaluate(X_test, y_test)
print(f"Akurasi: {acc}")
# Out:
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.2984 - loss: 2.0519
# Epoch 2/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3406 - loss: 1.5445
# Epoch 3/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3066 - loss: 1.3322
# Epoch 4/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.2879 - loss: 1.1902
# Epoch 5/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.3244 - loss: 1.0729
# Epoch 6/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.6807 - loss: 1.0075
# Epoch 7/50
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7093 - loss: 0.9918
# Epoch 8/50
# ...

# %% [markdown]
# ## Bandingkan akurasi dengan konfigurasi awal.

# %% [markdown]
# Modifikasi arsitektur model menghasilkan peningkatan akurasi yang signifikan, naik dari 93,33% menjadi 96,67%. Peningkatan performa ini dapat dikaitkan dengan penambahan jumlah neuron pada hidden layers yang secara langsung memperbesar kapasitas representasional (representational capacity) model.
#
# Dengan jumlah neuron yang lebih banyak, jaringan saraf memiliki fleksibilitas lebih tinggi untuk memetakan hubungan non-linear yang kompleks antar fitur input. Hal ini memungkinkan model membentuk decision boundary (batas keputusan) yang lebih presisi dalam membedakan ketiga kelas spesies. Namun, perlu dicatat bahwa peningkatan kompleksitas model ini membawa trade-off: risiko terjadinya overfitting meningkat, di mana model mungkin mulai menghafal noise pada data latih alih-alih mempelajari pola umum, jika kapasitasnya terlalu berlebihan dibandingkan jumlah data.

# %% [markdown]
# # Tugas 3

# %% [markdown]
# ## Bandingkan Sigmoid vs ReLU pada dataset Iris.
#
# ## Catat perbedaan loss dan akurasi.

# %%
print("\n" + "="*70)
print("TUGAS 3: PERBANDINGAN FUNGSI AKTIVASI (SIGMOID VS RELU)")
print("="*70)

# Konfigurasi untuk perbandingan aktivasi
configs_tugas3 = [
    {"name": "ReLU - Konfigurasi Awal", "layers": [10, 8], "activation": "relu"},
    {"name": "Sigmoid - Konfigurasi Awal", "layers": [10, 8], "activation": "sigmoid"},
    {"name": "ReLU - Hidden Layer Besar", "layers": [32, 16], "activation": "relu"},
    {"name": "Sigmoid - Hidden Layer Besar", "layers": [32, 16], "activation": "sigmoid"},
]

results_tugas3 = []

for config in configs_tugas3:
    print(f"\n{config['name']}")

    # Bangun model
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(config['layers'][0], activation=config['activation'], input_shape=(4,)))

    for neurons in config['layers'][1:]:
        model.add(tf.keras.layers.Dense(neurons, activation=config['activation']))

    model.add(tf.keras.layers.Dense(3, activation='softmax'))

    # Kompilasi
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

    # Latih model
    history = model.fit(X_train, y_train, epochs=50, batch_size=8, verbose=0, validation_split=0.2)

    # Evaluasi
    loss, acc = model.evaluate(X_test, y_test, verbose=0)

    # Ambil loss terakhir dari training
    final_train_loss = history.history['loss'][-1]
    final_train_acc = history.history['accuracy'][-1]

    results_tugas3.append({
        'Konfigurasi': config['name'],
        'Fungsi Aktivasi': config['activation'].upper(),
        'Arsitektur': str(config['layers']),
        'Train Loss': round(final_train_loss, 4),
        'Test Loss': round(loss, 4),
        'Train Acc': round(final_train_acc, 4),
        'Test Acc': round(acc, 4),
        'Test Acc (%)': round(acc * 100, 2)
    })

    print(f"Train Loss: {final_train_loss:.4f}, Test Loss: {loss:.4f}")
    print(f"Train Acc: {final_train_acc:.4f}, Test Acc: {acc:.4f} ({acc*100:.2f}%)")

# Tampilkan hasil dalam tabel
df_tugas3 = pd.DataFrame(results_tugas3)
print("\n" + "="*70)
print("RINGKASAN HASIL TUGAS 3")
print("="*70)
print(df_tugas3.to_string(index=False))

print("\n" + "="*70)
print("KESIMPULAN")
print("="*70)
print("\nTUGAS 2 - Pengaruh Jumlah Neuron:")
best_config = df_tugas2.loc[df_tugas2['Akurasi'].idxmax()]
print(f"- Konfigurasi terbaik: {best_config['Konfigurasi']}")
print(f"- Arsitektur: {best_config['Arsitektur']}")
print(f"- Akurasi: {best_config['Akurasi (%)']:.2f}%")

print("\nTUGAS 3 - Perbandingan Sigmoid vs ReLU:")
relu_results = df_tugas3[df_tugas3['Fungsi Aktivasi'] == 'RELU']
sigmoid_results = df_tugas3[df_tugas3['Fungsi Aktivasi'] == 'SIGMOID']

print(f"- Rata-rata akurasi ReLU: {relu_results['Test Acc'].mean():.4f}")
print(f"- Rata-rata akurasi Sigmoid: {sigmoid_results['Test Acc'].mean():.4f}")
print(f"- Rata-rata loss ReLU: {relu_results['Test Loss'].mean():.4f}")
print(f"- Rata-rata loss Sigmoid: {sigmoid_results['Test Loss'].mean():.4f}")

if relu_results['Test Acc'].mean() > sigmoid_results['Test Acc'].mean():
    print("\n- ReLU menunjukkan performa lebih baik pada dataset Iris")
else:
    print("\n- Sigmoid menunjukkan performa lebih baik pada dataset Iris")

print("\n" + "="*70)
# Out:
# ...
# TUGAS 3: PERBANDINGAN FUNGSI AKTIVASI (SIGMOID VS RELU)
# ...
#
# ReLU - Konfigurasi Awal
# Train Loss: 0.3224, Test Loss: 0.3041
# Train Acc: 0.9479, Test Acc: 0.9000 (90.00%)
#
# Sigmoid - Konfigurasi Awal
# Train Loss: 0.8152, Test Loss: 0.8052
# Train Acc: 0.7396, Test Acc: 0.7667 (76.67%)
#
# ReLU - Hidden Layer Besar
# Train Loss: 0.2136, Test Loss: 0.1964
# Train Acc: 0.9688, Test Acc: 0.9667 (96.67%)
#
# Sigmoid - Hidden Layer Besar
# Train Loss: 0.4283, Test Loss: 0.4044
# Train Acc: 0.9583, Test Acc: 0.9667 (96.67%)
#
# ...
# RINGKASAN HASIL TUGAS 3
# ...
#                  Konfigurasi Fungsi Aktivasi Arsitektur  Train Loss  Test Loss  Train Acc  Test Acc  Test Acc (%)
#      ReLU - Konfigurasi Awal            RELU    [10, 8]      0.3224     0.3041     0.9479    0.9000         90.00
#   Sigmoid - Konfigurasi Awal         SIGMOID    [10, 8]      0.8152     0.8052     0.7396    0.7667         76.67
# ...
